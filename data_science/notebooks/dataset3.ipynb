# %%
pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /opt/conda/lib/python3.11/site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine, MetaData

con_str = "postgresql+psycopg2://user:password@postgres:5432/datascience"
engine = create_engine(con_str)
conn = engine.connect()
conn

# %%
def list_table():
    # Create an engine
    engine = create_engine(con_str)
    
    # Create a MetaData object
    metadata = MetaData()
    
    # Reflect the tables from the database
    metadata.reflect(bind=engine)
    
    # Print the names of all tables
    print("Tables in the database:")
    for table in metadata.tables.values():
        print(table.name)

list_table()
# Out:
# Tables in the database:
# dataset3
# About Project_Mock Data
# About Project_Detail_Product_Mock Data
# About Herb - เวชกรรมไทย
# dataset1
# dataset2

# %%
import pandas as pd 
df = pd.read_csv("About Herb - เวชกรรมไทย (1).csv")
df
# Out:
#     ธาตุ ภาษาบาลีของธาตุ             ภาษาบาลี                 ภาษาไทย  \
# 0   ดิน๔        ปถวีธาตุ     มัตเกมัตถถลุงคัง            สมอง มันสมอง
# 1   ดิน๓        ปถวีธาตุ               วักกัง                    ม้าม
# 2   ดิน๓        ปถวีธาตุ                หทยัง                   หัวใจ
# 3   ดิน๓        ปถวีธาตุ                ยกนัง                     ตับ
# 4   ดิน๓        ปถวีธาตุ             กิโลมกัง                  พังผืด
# 5   ดิน๓        ปถวีธาตุ               ปิหกัง                      ไต
# 6   ดิน๓        ปถวีธาตุ             ปัปผาสัง                     ปอด
# 7   ดิน๓        ปถวีธาตุ               อันตัง               ลำไส้ใหญ่
# 8   ดิน๓        ปถวีธาตุ            อันตคุณัง               ลำไส้เล็ก
# 9   ดิน๒        ปถวีธาตุ               มังสัง        เนื้อ กล้ามเนื้อ
# 10  ดิน๒        ปถวีธาตุ                นหารู                    เอ็น
# 11  ดิน๒        ปถวีธาตุ                อัฎฐิ                  กระดูก
# 12  ดิน๒        ปถวีธาตุ          อัฏฐิมิญชัง  ไขกระดูก เยื่อในกระดูก
# 13  ดิน๑        ปถวีธาตุ                 เกศา                      ผม
# 14  ดิน๑        ปถวีธาตุ                 โลมา                      ขน
# 15  ดิน๑        ปถวีธาตุ                  นขา                    เล็บ
# 16  ดิน๑        ปถวีธาตุ                ทันตา                     ฟัน
# 17  ดิน๑        ปถวีธาตุ                 ตะโจ                    หนัง
# 18   ดิน        ปถวีธาตุ             อุทริยัง               อาหารใหม่
# 19   ดิน        ปถวีธาตุ               กรีสัง               อาหารเก่า
# 20   น้ำ        อาโปธาตุ               ปิตตัง                   น้ำดี
# 21   น้ำ        อาโปธาตุ              ศอเสมหะ                    เสลด
# 22   น้ำ        อาโปธาตุ            อุระเสมหะ                    เสลด
# 23   น้ำ        อาโปธาตุ             คูถเสมหะ                    เสลด
# 24   น้ำ        อาโปธาตุ                บุปโพ       น้ำเหลือง น้ำหนอง
# 25   น้ำ        อาโปธาตุ             โลหิตตัง                   เลือด
# 26   น้ำ        อาโปธาตุ                 เสโท               น้ำเหงื่อ
# 27   น้ำ        อาโปธาตุ                 เมโท                  มันข้น
# 28   น้ำ        อาโปธาตุ                อัสสุ                   น้ำตา
# 29   น้ำ        อาโปธาตุ                  วสา                 มันเหลว
# 30   น้ำ        อาโปธาตุ                 เขโฬ                  น้ำลาย
# 31   น้ำ        อาโปธาตุ            สิงฆานิกา                  น้ำมูก
# 32   น้ำ        อาโปธาตุ                ลสีกา                น้ำไขข้อ
# 33   น้ำ        อาโปธาตุ               มุตตัง      น้ำมูตร น้ำปัสสาวะ
# 34    ลม        วาโยธาตุ        อุทธังคมาวาตา             ลมพัดขึ้นบน
# 35    ลม        วาโยธาตุ           อโธคมาวาตา       ลมพัดลงเบื้องล่าง
# 36    ลม        วาโยธาตุ         กุจฉิสยาวาตา         ลมที่อยู่ในท้อง
# 37    ลม        วาโยธาตุ         โกฎฐาสยาวาตา        ลมที่อยู่ในลำใส้
# 38    ลม        วาโยธาตุ  อังคมังคานุสารีวาตา    ลมที่อยู่ทั่วร่างกาย
# 39    ลม        วาโยธาตุ   อัสสาสะปัสสาสะวาตา                 ลมหายใจ
# 40    ไฟ        เตโชธาตุ          สันตัปปัคคี               ไฟอุ่นกาย
# 41    ไฟ        เตโชธาตุ          ปริทัยหัคคี   ไฟทำให้ร้อนระส่ำระสาย
# 42    ไฟ        เตโชธาตุ             ชีรณัคคี   ไฟทำให้ร่างกายรุดโทรม
# 43    ไฟ        เตโชธาตุ           ปริณามัคคี             ไฟย่อยอาหาร
#
#                                                กำเริบ  \
# 0   ผมแตกปลาย/ผมหงอก/หนังศีรษะมันเยิ้ม/คันหนังศีรษ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  เหงื่อออกมาก/เจ็บทั่วทุกขุมขน/ให้ขนพองขนชันทั่วไป
# 15                                            เล็บคุด
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  ให้ตกอุจจาระเป้นเสมหะเป็นมูกและโลหิต/ปวดท้อง/เ...
# 24               ผื่นคัน/เป็นตุ่มเบื่อย/คันตามร่างกาย
# 25  ให้เจ็บตามแขนขา/โลหิตระดูออกมามีกลิ่นเหม็น/ออก...
# 26  เหงื่อออกมาก/อ่อนเพลีย/เป็นตะคริว/มีกลิ่นตัวเห...
# 27  อ่อนเพลีย/ทำงานแกกำลังเพียงเล็กน้อยก็เหนื่อยหอ...
# 28                        น้ำตาไหลมาก/ตาแฉะ/ปวดเบ้าตา
# 29            ผิวหนังมันเยิ้ม/ทำให้ตโจเป็นฝีหนอง(สิว)
# 30                     น้ำลายมาก/ไหลเลอะเทอะ/ปากเหม็น
# 31   คัดจมูก/ให้ปวดในสมอง/ให้ตามัวให้น้ำมูกตก/เป็นไข้
# 32                 ข้อบวม/ให้เจ็บปวดตามข้อ/แท่งกระดูก
# 33  รู้สึกเจ็บและไม่สบายในท้อง/ในท้องน้อย/ปัสสาวะบ...
# 34  ให้ดิ้นรนมือและเท้าขวักไขว่/ให้พริกตัวไปๆมาๆ/ใ...
# 35                              ชักกระตุก/มือเท้าสั่น
# 36  ให้ท้องลั่นอยู่จ็อกๆ/หิวบ่อย/ท้องเดิน/ปวดท้อง/...
# 37     จุกเสียดแน่น/ให้ขัดอก/ให้อาเจียน/ปวด/เสียดท้อง
# 38  ให้โสตประสาทตึงเจรจาไม่ได้ยิน/ให้เป็นหิ่งห้อยอ...
# 39                 ให้หายใจไม่สะดวก/หายใจถี่/เหงื่อตก
# 40                                    ตัวร้อน/เป็นไข้
# 41                      ตัวร้อนจัด/ให้ร้อนภายในภายนอก
# 42  แก่เร็วให้แก่คร่ำคร่า/ให้หน้าผากตึง/หูตึง/นัยน...
# 43                    หิวบ่อย/ปวดแสบท้อง/ร้อนในอกในใจ
#
#                                                 หย่อน  \
# 0         เส้นผมมีสีจางลง/คันหนังศีรษะ/หนังศีระษะแห้ง
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                    เหงื่อออกน้อย/ขนล้ม/ผิวหนังแห้ง
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                      ให้กายซูบผอม/กินอาหารไม่รู้รส
# 25  ทำให้โลหิตระดูมาน้อย/ไม่มีระดู/เจ็ยปวดที่อวัยว...
# 26  เหงื่อออกน้อย/ผิวหนังแตก/ผิวหนังมีความรู้สึกผิ...
# 27  ผอมแห้ง/สะเอวบาง/ท้องน้อยเล็ก/รู้สึกข้อหลวม/ข้...
# 28                          ตาแห็งฝืด/แสบตา/ปวดเบ้าตา
# 29                             ผิวหนังแห้ง/คัน/แตกแยก
# 30            น้ำลายเหนียว/เจ็บคอ/กระหายน้ำ/ปากคอแห้ง
# 31                                   แสบจมูก/จมูกแห็ง
# 32                ข้อแห้ง/ให้เจ็บปวดตามข้อ/แท่งกระดูก
# 33  ถ่ายปัสสาวะกระปริดกระปอยและไม่ค่อยออก/เจ็บกระเ...
# 34                ไม่รู้สึกสัมผัส/ปสาทรูป๕ทำงานน้อยลง
# 35  ให้ยกมือและเท้าไม่ไหว/ให้เมื่อย/ขบไปทุกข้อ/เคล...
# 36                  ท้องอืด/ท้องผูก/ถ่ายปัสสาสะไม่หมด
# 37               ท้องผูก/เป็นพรรดึก/ผายลมมีกลิ่นเหม็น
# 38  เป็นลม/วิงเวียนหน้ามืด/ให้เมื่อยมือและเท้า/กิน...
# 39                    ให้หายใจไม่สะดวก/หายใจสั้นเข้าๆ
# 40                                   ตัวเย็น/หนาวสั่น
# 41                                มือเท้าเย็น/ตัวเย็น
# 42                                                NaN
# 43              ให้ท้องแข็ง/พะอีดพะอม/ท้องขึ้นท้องพอง
#
#                                                 พิการ
# 0   ผมร่วง/ผมหัก/ขาดง่าย/หนังศีรษะเป็นรังแค/ติดเชื...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  ขนร่วง/เจ็บทุกรูขุมขน/รูขุมขนอุดตัน/รูขุมขนอักเสบ
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                       มีน้ำหนองไหลออก/เนืองๆ/ฟกบวม
# 25  ไข้ตัวร้อน/ให้เพ้อคลั่ง/ปัสสาวะแดง/เป็นเม็ดตาม...
# 26  ให้สวิงสวาย/ให้ตัวเย็น/ตัวขาวซีด/สากชาไปทั้งตั...
# 27  ผุดเป็นแผ่นตามผิวหนัง/เป็นวง/เป็นดวง/ให้ปวดแสบ...
# 28                          ตาเป็นฝ้า/ตาแฉะ/ตาเป็นต้อ
# 29  ให้ผิวเหลือง ตาเหลือง ให้ลงท้อง(มีวสามากเกินไป...
# 30                       เป็นเม็ดยอดขึ้นในลำคอ/เจ็บคอ
# 31       ริดสีดวงจมูก/มีโลหิต/หนอง/มีกลิ่นเหม็นในจมูก
# 32                    เป็นจับโปงน้ำ/จับโปงแห้ง/ข้อติด
# 33  ให้ปัสสาสะเป็นสีต่างๆ/มีเลือด/มีหนอง/เป็นตะกอน...
# 34                ไม่รู้สึกสัมผัส/ปสาทรูป๕ทำงานน้อยลง
# 35  ให้ยกมือและเท้าไม่ไหว/ให้เป้นอัมพาต/เคลื่อนไหวช้า
# 36  ไม่ถ่ายอุจจาระปัสสาวะ/ให้อาเจียนรุนแรง/เจ็บในอ...
# 37               ท้องผูก/เป็นพรรดึก/ผายลมมีกลิ่นเหม็น
# 38  ให้นัยน์ตาพร่า/ให้วิงเวียน/ให้เจ็บสองหน้าแข็งด...
# 39           หายใจไม่ออกไม่เข้า/หมดลมมหายใจ/เสียชีวิต
# 40                ร่างกายเย็นชืด/เริ่มตั้งแต่ปลายเท้า
# 41  ตัวเย็นแต่ภายในร้อนรดน้ำมิได้าด/เหงื่อตกดังเม็...
# 42  มีอาการมากขึ้นจากกำเริบ/ให้ร่างกายเหี่ยวแห้งทร...
# 43  ให้ขัดข้อมือข้อเท้า/เป็นหวัด/ให้ไอ/ปวดฝ่ามือฝ่...

# %%
df.to_sql(name='About Herb - เวชกรรมไทย', con=con_str, index=False ,if_exists='replace' )
# Out:
# 44
