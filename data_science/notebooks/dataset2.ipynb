# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine, MetaData

con_str = "postgresql+psycopg2://user:password@postgres:5432/datascience"
engine = create_engine(con_str)
conn = engine.connect()
conn

# %%
def list_table():
    # Create an engine
    engine = create_engine(con_str)
    
    # Create a MetaData object
    metadata = MetaData()
    
    # Reflect the tables from the database
    metadata.reflect(bind=engine)
    
    # Print the names of all tables
    print("Tables in the database:")
    for table in metadata.tables.values():
        print(table.name)

list_table()
# Out:
# Tables in the database:
# dataset3
# About Project_Mock Data
# About Project_Detail_Product_Mock Data
# About Herb - เวชกรรมไทย
# dataset1
# dataset2

# %%
import pandas as pd 
df = pd.read_csv("About Project_Detail_Product_Mock Data - Herb with Cough Syrub.csv")
df
# Out:
#                     Card_ID                      link_card  \
# 0  662e0feac9d95c7a8f602aba  https://trello.com/c/pZtZLreA
# 1  662e0e414fe69fed04690ec2  https://trello.com/c/hPo6KtGK
# 2  662e045f80fdc7643b412239  https://trello.com/c/6wcECFIe
# 3  662e0447d06068cc82910ae5  https://trello.com/c/FkyyfYJ2
# 4  662e025e8305c2bf6519d8a8  https://trello.com/c/EuJNeK6f
# 5  662e01d8f3545162b9f59222  https://trello.com/c/ioF2NH2f
# 6  662e0126df0d7c7dccc14f2f  https://trello.com/c/BDhKezPG
# 7  662dffc4d65f6a08c1aa228c  https://trello.com/c/xQloA6ge
# 8  662a16ac31b391624a3f4e17  https://trello.com/c/AlOpGMhu
# 9  662a16046b131efac8fe6419  https://trello.com/c/Wch5g5QJ
#
#                                                title  \
# 0                 ข้อปฎิบัติทั่วไปและเอกสารเพิ่มเติม
# 1  บันทึกกระบวนการผลิต การบรรจุ การควบคุมคุณภาพแล...
# 2                                        ค่าจ้าง Lab
# 3                                        ค่าเสียเวลา
# ...

# %%
df.to_sql(name='About Project_Detail_Product_Mock Data', con=con_str, index=False, if_exists='replace')
# Out:
# 10
